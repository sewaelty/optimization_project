# %%
import pandas as pd
import numpy as np
import gurobipy as gp
from gurobipy import GRB
import os
import sys
from datetime import datetime
import itertools
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Loading Data

# %%
# Get the absolute path to the 'src' directory
project_root = os.path.abspath(os.path.join(os.getcwd(), "..", "..")) #change when running in a different directory
data_dir = os.path.join(project_root, "data")
src_path = os.path.join(project_root, "src")

# Add 'src' to system path
if src_path not in sys.path:
    sys.path.append(src_path)

from create_Dataframe import createDataframe as create_df
merged_data_summer = create_df('summer')
# Out:
# c:\Users\aless\Documents\Personal docs\Studium\Master Energy Science and Technology\2. Semester\Optimization in Energy Systems\optimization_project\src\create_Dataframe.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pv_summer["timestamp"] = pd.to_datetime(
# c:\Users\aless\Documents\Personal docs\Studium\Master Energy Science and Technology\2. Semester\Optimization in Energy Systems\optimization_project\src\create_Dataframe.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pv_winter["timestamp"] = pd.to_datetime(

# %% [markdown]
# ### Dishwasher

# %%
# Load data
price = merged_data_summer["Spotmarket_(EUR/kWh)"].values
inflexible_demand = merged_data_summer['Inflexible_Demand_(kWh)'].values

Time_interval = len(price)  # Total time interval in hours

# Dishwasher properties
duration = 3  # hours of operation
min_gap = 15  # hours between runs
power_dishwasher = 1.5  # kW during operation

# Gurobi model
model = gp.Model("automated_demand_response")

# Binary start variables: 1 if dishwasher starts at hour t
start_times = range(Time_interval - duration + 1)
dishwasher_start = model.addVars(start_times, vtype=GRB.BINARY, name="start")

# Binary on variables: 1 if dishwasher is on at hour t
binary_dishwasher = model.addVars(Time_interval, vtype=GRB.BINARY, name="on")

for t, k in itertools.product(range(len(start_times)), range(duration)):
    model.addConstr(binary_dishwasher[t + k] >= dishwasher_start[t], name=f"dishwasher_{t}_{k}")

for t in range(len(start_times)-1):
    model.addConstr(gp.quicksum(binary_dishwasher[t + k] for k in range(duration+1)) <= 3, name=f"max_three_hours_on_{t}")


# Enforce min 1 run per day
#adds up all possible start times of the dishwasher in a single and '>= 1' day ensures that the dishwasher has to run once per day
hours_per_day = 24
days = Time_interval // hours_per_day
for d in range(days-1):
    model.addConstr(gp.quicksum(dishwasher_start[t] for t in range(d * 24, (d + 1) * 24)) == 1,
                name=f"min_one_run_per_day_dishwasher_{d}")
    
# Enforce max 1 run per day of max 3 hours
#adds up all possible start times of the dishwasher in a single and '<= 1' day ensures that the dishwasher doesn't run more than once per day
hours_per_day = 24
days = Time_interval // hours_per_day
for d in range(days-1):
    model.addConstr(gp.quicksum(binary_dishwasher[t] for t in range(d * 24, (d + 1) * 24)) == 3,
                name=f"max_one_run_per_day_dishwasher_{d}")

# Enforce minimum gap (15 hours) between two starts
#multiplying with min_gap so we don't constrain the dishwasher to start at the same time every day
#this enures that the optimizer can iterate through without being constrained to a single time
for t in range(len(start_times)-min_gap):
    model.addConstr(gp.quicksum(dishwasher_start[t + offset] for offset in range(1, min_gap + 1)) <= (1 - dishwasher_start[t]) * min_gap,
                name=f"min_gap_after_{t}")

model.update()
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2649317
# Academic license - for non-commercial use only - expires 2026-04-09

# %% [markdown]
# ### Washing Machine

# %%
### including the washing machine
# washing_machine properties
duration_wm = 2  # hours of operation
min_gap_wm = 1  # hours between runs
power_wm = 3  # kW during operation -> should be double checked
wm_runs_per_week = 4

binary_wm = model.addVars(Time_interval, vtype=GRB.BINARY, name="on_wm")

# Binary start variables: 1 if washing machine starts at hour t

start_times_wm = range(Time_interval - duration_wm + 1)
wm_start = model.addVars(start_times_wm, vtype=GRB.BINARY, name="start_wm")

# Binary on variables: 1 if washing machine is on at hour t

binary_wm = model.addVars(Time_interval, vtype=GRB.BINARY, name="on_wm")

# When washing machine is on, it must be running -> wm_start is 1 -> binary_wm at the same time + duration_wm is 1 

for t, k in itertools.product(range(len(start_times_wm)), range(duration_wm)):
    model.addConstr(binary_wm[t + k] >= wm_start[t], name=f"wm_{t}_{k}")

for t in range(len(start_times_wm)-duration_wm):
    model.addConstr(gp.quicksum(binary_wm[t + k] for k in range(duration_wm+1)) <= duration_wm, name=f"wm_max_two_hours_on_{t}")


# Enforce min 4 runs per week -> if negative prices, can run more than 4 times, for now: exactly 4 times
#adds up all possible start times of the washing machine in a single week and '>= 1' day ensures that the washing machine has to run 4 times per week

hours_per_week = 24*7
weeks = Time_interval // hours_per_week
for week in range(weeks):
    model.addConstr(gp.quicksum(wm_start[t] for t in range(week * 24 * 7, (week + 1) * 24 * 7 -1)) == wm_runs_per_week,
                name=f"wm_four_runs_per_week_{week}")


# Enforce minimum gap (1 hour) between two starts
for t in range(len(start_times_wm)-min_gap_wm):
    model.addConstr(gp.quicksum(wm_start[t + offset] for offset in range(1, min_gap_wm + 1)) <= (1 - wm_start[t]) * min_gap_wm,
                name=f"min_gap_after_washing_wm_{t}")
    
#washing machine can only run during certain hours of the day, during the week after 4pm and on weekends after 10am
# Add a new column to the dataframe indicating when the washing machine can be turned on
merged_data_summer['Allowed_WM_summer'] = 0  # Initialize with 0

# Define the conditions for weekdays and weekends -> for summer and winter
for index, row in merged_data_summer.iterrows():
    hour = row['timestamp'].hour
    day_of_week = row['timestamp'].weekday()  # Monday=0, Sunday=6
    if (day_of_week < 5 and 16 <= hour < 20) or (day_of_week >= 5 and 8 <= hour < 20):
        merged_data_summer.loc[index, 'Allowed_WM_summer'] = 1
    else: 
        merged_data_summer.loc[index, 'Allowed_WM_summer'] = 0
        
model.addConstrs((binary_wm[t] <= merged_data_summer['Allowed_WM_summer'][t] for t in range(len(binary_wm))), name="allowed_wm_summer")

model.update()

# %% [markdown]
# ### Dryer

# %%
### including the dryer
# dryer properties
duration_dryer = 2  # hours of operation
max_gap_wm_dryer = 2  # hours between washing machine end and dryer start
power_dryer = 3  # kW during operation -> should be double checked


binary_dryer = model.addVars(Time_interval, vtype=GRB.BINARY, name="on_dryer")

# Binary start variables: 1 if dryer starts at hour t

start_times_dryer = range(Time_interval - duration_dryer + 1)
dryer_start = model.addVars(start_times_dryer, vtype=GRB.BINARY, name="start_dryer")

# Binary on variables: 1 if dryer is on at hour t

binary_dryer = model.addVars(Time_interval, vtype=GRB.BINARY, name="on_dryer")

# When dryer is on, it must be running -> dryer_start is 1 -> binary_dryer at the same time + duration_dryer is 1 

for t, k in itertools.product(range(len(start_times_dryer)), range(duration_dryer)):
    model.addConstr(binary_dryer[t + k] >= dryer_start[t], name=f"dryer_{t}_{k}")

for t in range(len(start_times_dryer)-duration_dryer):
    model.addConstr(gp.quicksum(binary_dryer[t + k] for k in range(duration_dryer+1)) <= duration_dryer, name=f"dryer_max_two_hours_on_{t}")


# Enforce minimum gap of 0 hours and max gap of 2 hours between two end of washing machine and start of dryer



# Enforce that the dryer starts within max_gap_wm_dryer hours after the washing machine ends
for t in range(len(dryer_start)-max_gap_wm_dryer-duration_wm):
    model.addConstr(gp.quicksum(dryer_start[t + offset + duration_wm] for offset in range(0, max_gap_wm_dryer + 1)) >= wm_start[t],
                name=f"max_gap_after_washing_dryer_{t}")



#washing machine can only run during certain hours of the day, during the week after 4pm and on weekends after 10am
# Add a new column to the dataframe indicating when the washing machine can be turned on
merged_data_summer['Allowed_dryer_summer'] = 0  # Initialize with 0

# Define the conditions for weekdays and weekends -> for summer and winter
for index, row in merged_data_summer.iterrows():
    hour = row['timestamp'].hour
    day_of_week = row['timestamp'].weekday()  # Monday=0, Sunday=6
    if (day_of_week < 5 and 16 <= hour < 22) or (day_of_week >= 5 and 8 <= hour < 22):
        merged_data_summer.at[index, 'Allowed_dryer_summer'] = 1
    else: 
        merged_data_summer.at[index, 'Allowed_dryer_summer'] = 0

model.addConstrs((binary_dryer[t] <= merged_data_summer['Allowed_dryer_summer'][t] for t in range(len(binary_dryer))), name="allowed_dryer_summer")

model.update()

# %% [markdown]
# ### EV - G2V

# %%
# Include EV
# EV properties

min_power_ev = 1 #kW, minimum power to charge the EV
max_power_ev = 10 #kW, maximum power to charge the EV
kwh_per_km = 0.2  # kWh per km driven

max_capacity_ev = 70 #kWh

#Variables

#state of charge of the EV at each time step
soc_ev = model.addVars(Time_interval,lb=0, ub=max_capacity_ev, vtype=GRB.CONTINUOUS, name="soc_ev")
#how much power is being charged at each time step
charging_ev = model.addVars(Time_interval,lb=0, ub=max_power_ev, vtype=GRB.CONTINUOUS, name="charging_lvl_ev")
#binary variable to indicate if the EV is being charged at each time step
binary_ev = model.addVars(Time_interval, vtype=GRB.BINARY, name="on_ev")


# Enforce SoC at 7:00 every day (hour 7 of each day)
for d in range(Time_interval // 24):
    t = d * 24 + 7  # 7:00 each day
    if t < Time_interval:
        model.addConstr(soc_ev[t] >= 0.8*max_capacity_ev, name=f"ev_soc_7am_day_{d}")

# car can only charge if it is at home
model.addConstrs((binary_ev[t] <= merged_data_summer['ev_at_home_binary'][t] for t in range(len(binary_ev))), name="allowed_ev_summer")

# if car is at home, it can charge, but not more than the maximum power
# and if it is charging, it must be charging at least the minimum power
model.addConstrs((charging_ev[t] <= max_power_ev * merged_data_summer['ev_home_availability'][t] * binary_ev[t] for t in range(Time_interval)), name="max_power_ev")
model.addConstrs((charging_ev[t] >= min_power_ev * merged_data_summer['ev_home_availability'][t] * binary_ev[t] for t in range(Time_interval)), name="min_power_ev")

# Constrain ev storage

initial_soc_ev = 20
model.addConstr(soc_ev[0] == initial_soc_ev, name="ev_soc_initial")

model.addConstrs((soc_ev[t] == soc_ev[t-1] + charging_ev[t-1] - merged_data_summer['distance_driven'][t-1] * kwh_per_km for t in range(1,Time_interval)),name="ev_soc_update")

model.update()

# %% [markdown]
# ### Peak Price
# If everyone implements this optimization, the price will have to be higher at peak times

# %%
ε = 1e-3
wanted_steps = 3
max_demand = max(inflexible_demand) + power_dishwasher + power_wm + power_dryer + max_power_ev
levels = np.arange(0, max_demand/2 + ε, max_demand/((wanted_steps -1)*2))
levels = np.append(levels, max_demand * 1.5 + 5)  # Ensure coverage

#multipllier for penalty costs per level increasing by 0.1 per level
multiplier_per_level = [0.05 * i for i in range(len(levels)-1)]
M_price = max_demand + 10

# Binary indicators per level per timestep
level_bin = [
    [model.addVar(vtype=GRB.BINARY, name=f"level_bin[{t},{i}]") for i in range(len(levels)-1)]
    for t in range(Time_interval)
]

# Integer index of active level
demand_level = [
    model.addVar(lb=0, ub=len(levels) - 1, vtype=GRB.INTEGER, name=f"demand_level[{t}]")
    for t in range(Time_interval)
]

# Total demand per timestep
total_demand = model.addVars(Time_interval, lb=0, ub=max_demand, vtype=GRB.CONTINUOUS, name="total_demand")

# Constraint: calculate total demand
for t in range(Time_interval):
    model.addConstr(
        total_demand[t] ==
        merged_data_summer['Inflexible_Demand_(kWh)'][t] +
        power_dishwasher * binary_dishwasher[t] +
        power_wm * binary_wm[t] +
        power_dryer * binary_dryer[t] +
        charging_ev[t]
    )

# Constraint: only one level active at a time
for t in range(Time_interval):
    model.addConstr(gp.quicksum(level_bin[t]) == 1, name=f"one_level_active_{t}")

# Constraint: bind total_demand to its level using Big-M
for t in range(Time_interval):
    for i in range(len(levels) - 1):
        model.addConstr(
            total_demand[t] >= levels[i] - (1 - level_bin[t][i]) * M_price,
            name=f"lower_bound_level_{t}_{i}"
        )
        model.addConstr(
            total_demand[t] <= levels[i + 1] - ε + (1 - level_bin[t][i]) * M_price,
            name=f"upper_bound_level_{t}_{i}"
        )
    # Calculate demand_level from binary selection
    model.addConstr(
        demand_level[t] == gp.quicksum(i * level_bin[t][i] for i in range(len(levels)-1)),
        name=f"demand_level_calc_{t}"
    )

#generate penalty costs for each level that depend on a const and a linear term
penalty_per_level = [multiplier_per_level[i] * levels[i] for i in range(len(levels)-1)]



# Penalty term as an expression
penalty_cost = gp.quicksum(
    penalty_per_level[i] * level_bin[t][i]
    for t in range(Time_interval)
    for i in range(len(levels)-1)
)

print(levels)
print(multiplier_per_level)
print(penalty_per_level)

model.update()
# Out:
# [ 0.          5.32008676 10.64017351 36.92052054]
# [0.0, 0.05, 0.1]
# [np.float64(0.0), np.float64(0.2660043378280649), np.float64(1.0640173513122595)]

# %% [markdown]
# ### Objective Function and Optimization

# %%
# Electricity cost
electricity_cost = gp.quicksum(
    (price[t] *
        (merged_data_summer['Inflexible_Demand_(kWh)'][t] +
        power_dishwasher * binary_dishwasher[t] +
        power_wm * binary_wm[t] +
        power_dryer * binary_dryer[t] +
        charging_ev[t])) for t in range(Time_interval)
)

# Full objective: cost + penalty
model.setObjective(electricity_cost + penalty_cost, GRB.MINIMIZE)

# Optimize
model.optimize()
# Out:
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) Ultra 7 155H, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 22 logical processors, using up to 22 threads
#
# Optimize a model with 20884 rows, 11900 columns and 60213 nonzeros
# Model fingerprint: 0x435c6df2
# Variable types: 2232 continuous, 9668 integer (8924 binary)
# Coefficient statistics:
#   Matrix range     [3e-01, 3e+01]
#   Objective range  [2e-03, 1e+00]
#   Bounds range     [1e+00, 7e+01]
#   RHS range        [7e-02, 7e+01]
#
# MIP start from previous solve produced solution with objective 93.011 (0.02s)
# MIP start from previous solve produced solution with objective 93.011 (0.03s)
# Loaded MIP start from previous solve with objective 93.011
#
# Presolve removed 15841 rows and 6863 columns
# Presolve time: 0.11s
# Presolved: 5043 rows, 5037 columns, 25736 nonzeros
# Found heuristic solution: objective 92.9131137
# Variable types: 734 continuous, 4303 integer (4303 binary)
# Found heuristic solution: objective 91.6961337
#
# Root relaxation: objective 4.437938e+01, 2858 iterations, 0.02 seconds (0.03 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   44.37938    0  193   91.69613   44.37938  51.6%     -    0s
# H    0     0                      62.6215959   44.37938  29.1%     -    0s
# H    0     0                      61.1713959   44.37938  27.5%     -    0s
# H    0     0                      59.4695859   44.37938  25.4%     -    0s
# H    0     0                      58.8490715   44.37938  24.6%     -    0s
# H    0     0                      58.7836115   44.37938  24.5%     -    0s
# H    0     0                      55.4188562   44.37938  19.9%     -    0s
# H    0     0                      54.9116353   44.37938  19.2%     -    0s
# H    0     0                      54.0570353   44.37938  17.9%     -    0s
# H    0     0                      52.9283960   44.37938  16.2%     -    0s
# H    0     0                      51.8884817   44.37938  14.5%     -    0s
# H    0     0                      51.1210711   44.37938  13.2%     -    0s
# H    0     0                      51.0611911   44.37938  13.1%     -    0s
# H    0     0                      51.0267975   44.82296  12.2%     -    0s
# H    0     0                      50.9625075   44.82296  12.0%     -    0s
#      0     0   44.82296    0  237   50.96251   44.82296  12.0%     -    0s
# H    0     0                      50.9239575   44.84960  11.9%     -    0s
# H    0     0                      50.9209539   44.84960  11.9%     -    0s
# H    0     0                      50.8831539   44.84960  11.9%     -    0s
# H    0     0                      50.6778567   44.84960  11.5%     -    0s
# H    0     0                      50.5592741   44.84960  11.3%     -    0s
# H    0     0                      50.3342441   44.84960  10.9%     -    0s
# H    0     0                      49.8379191   44.84960  10.0%     -    0s
# H    0     0                      49.7319341   44.84960  9.82%     -    0s
# H    0     0                      49.6787583   44.84960  9.72%     -    0s
# H    0     0                      49.6108683   44.84960  9.60%     -    0s
# H    0     0                      49.3765677   44.84960  9.17%     -    0s
# H    0     0                      49.2913470   44.84960  9.01%     -    0s
# H    0     0                      49.2327270   44.84960  8.90%     -    0s
#      0     0   44.85393    0  250   49.23273   44.85393  8.89%     -    0s
#      0     0   45.24221    0  299   49.23273   45.24221  8.11%     -    0s
# H    0     0                      49.2317002   45.25091  8.09%     -    0s
#      0     0   45.28497    0  290   49.23170   45.28497  8.02%     -    0s
#      0     0   45.31053    0  275   49.23170   45.31053  7.96%     -    0s
#      0     0   45.31087    0  280   49.23170   45.31087  7.96%     -    0s
#      0     0   45.31087    0  278   49.23170   45.31087  7.96%     -    0s
#      0     0   45.61757    0  273   49.23170   45.61757  7.34%     -    0s
#      0     0   45.63713    0  280   49.23170   45.63713  7.30%     -    0s
#      0     0   45.63762    0  282   49.23170   45.63762  7.30%     -    0s
#      0     0   45.64336    0  285   49.23170   45.64336  7.29%     -    0s
#      0     0   45.64693    0  286   49.23170   45.64693  7.28%     -    0s
#      0     0   45.65186    0  288   49.23170   45.65186  7.27%     -    0s
#      0     0   45.65227    0  287   49.23170   45.65227  7.27%     -    0s
#      0     0   45.65240    0  290   49.23170   45.65240  7.27%     -    0s
#      0     0   45.71028    0  291   49.23170   45.71028  7.15%     -    0s
#      0     0   45.72114    0  294   49.23170   45.72114  7.13%     -    0s
#      0     0   45.72114    0  294   49.23170   45.72114  7.13%     -    0s
#      0     0   45.72114    0  293   49.23170   45.72114  7.13%     -    0s
#      0     0   45.72698    0  301   49.23170   45.72698  7.12%     -    0s
#      0     0   45.73162    0  302   49.23170   45.73162  7.11%     -    0s
#      0     0   45.73162    0  299   49.23170   45.73162  7.11%     -    0s
#      0     0   45.73766    0  312   49.23170   45.73766  7.10%     -    0s
#      0     0   45.74076    0  316   49.23170   45.74076  7.09%     -    0s
#      0     0   45.74076    0  317   49.23170   45.74076  7.09%     -    0s
#      0     0   45.75949    0  319   49.23170   45.75949  7.05%     -    0s
#      0     0   45.76547    0  319   49.23170   45.76547  7.04%     -    0s
#      0     0   45.76628    0  310   49.23170   45.76628  7.04%     -    0s
# H    0     0                      49.2188540   45.76932  7.01%     -    1s
#      0     0   45.76932    0  318   49.21885   45.76932  7.01%     -    1s
# H    0     0                      49.2157540   45.76932  7.00%     -    1s
# H    0     0                      49.2157040   45.76932  7.00%     -    1s
# H    0     0                      49.1884397   45.76932  6.95%     -    1s
# H    0     0                      49.1883897   45.76932  6.95%     -    1s
#      0     0   45.77028    0  316   49.18839   45.77028  6.95%     -    1s
#      0     2   45.77311    0  316   49.18839   45.77311  6.94%     -    1s
# H   38    48                      49.1168997   45.88662  6.58%  23.9    1s
# H   64    80                      49.1137297   45.88662  6.57%  17.7    1s
# H   69    80                      49.0517528   45.88662  6.45%  17.2    1s
# H 1102  1172                      49.0509153   45.88662  6.45%  13.1    1s
# H 1111  1172                      49.0179240   45.88662  6.39%  13.1    1s
# H 2484  2264                      49.0168540   46.08467  5.98%  13.2    2s
# H 2484  2087                      48.8086697   46.08467  5.58%  13.2    2s
# H 2484  1986                      48.6945967   46.08467  5.36%  13.2    2s
# H 2487  1872                      48.6788317   46.08467  5.33%  13.2    2s
# H 2487  1778                      48.6144274   46.08467  5.20%  13.2    2s
# H 2509  1703                      48.6114313   46.81705  3.69%  13.1    4s
# H 2513  1620                      48.5882413   46.89695  3.48%  13.0    4s
# H 2513  1539                      48.5571463   46.89695  3.42%  13.0    4s
# H 2518  1464                      48.5425174   46.96121  3.26%  13.0    4s
#   2523  1467   47.94559   47  324   48.54252   46.99294  3.19%  13.0    5s
# H 2584  1449                      48.4981734   47.34260  2.38%  16.1    7s
# H 2585  1377                      48.4979145   47.34260  2.38%  16.1    7s
# H 2851  1440                      48.4895595   47.38064  2.29%  16.3    8s
#   5713  1999   48.16293   33  195   48.48956   47.71240  1.60%  15.4   10s
# H 5727  1926                      48.4882095   47.72296  1.58%  15.4   10s
# *11135  4426              59      48.4872159   47.84636  1.32%  15.2   14s
#  11913  4754   48.27475   19  297   48.48722   47.86405  1.29%  15.3   15s
#  17108  6762   48.36693   32  165   48.48722   47.91769  1.17%  16.2   20s
#  20700  8049     cutoff   35        48.48722   47.95446  1.10%  16.8   25s
#  25509  9359   48.43944   22  253   48.48722   47.99087  1.02%  17.7   30s
# H25547  9353                      48.4862659   47.99087  1.02%  17.7   30s
#  27482 10392   48.08482   19  303   48.48627   47.99906  1.00%  18.0   35s
#  32511 11850     cutoff   41        48.48627   48.02550  0.95%  18.7   41s
#  35634 12655   48.44092   34  281   48.48627   48.04394  0.91%  19.0   45s
#  40347 13986   48.47312   40  165   48.48627   48.06433  0.87%  19.6   50s
#  42119 14440   48.30343   27  187   48.48627   48.07128  0.86%  19.8   64s
#  43486 15022   48.20423   32  259   48.48627   48.07486  0.85%  20.0   67s
#  47565 15855     cutoff   28        48.48627   48.08857  0.82%  20.4   72s
#  51236 16707     cutoff   28        48.48627   48.09936  0.80%  20.8   76s
#  54726 17384   48.26768   24  208   48.48627   48.10943  0.78%  21.1   81s
#  58257 18048   48.40802   38   99   48.48627   48.11813  0.76%  21.3   86s
#  61689 18585   48.38044   35  229   48.48627   48.12678  0.74%  21.5   91s
#  65259 19203     cutoff   30        48.48627   48.13573  0.72%  21.7   96s
#  70090 19989   48.35434   35  254   48.48627   48.14615  0.70%  22.0  102s
#  73449 20459   48.47677   33  135   48.48627   48.15192  0.69%  22.1  106s
#  77029 20922   48.31948   33  237   48.48627   48.15755  0.68%  22.3  111s
#  80591 21379     cutoff   31        48.48627   48.16342  0.67%  22.5  116s
#  83579 21811   48.19327   36  222   48.48627   48.16913  0.65%  22.7  121s
#  87012 22229   48.47021   30  150   48.48627   48.17463  0.64%  22.8  126s
#  90311 22673 infeasible   37        48.48627   48.17979  0.63%  22.9  130s
#  94090 23129   48.47805   41  140   48.48627   48.18553  0.62%  23.0  135s
#  97696 23460     cutoff   22        48.48627   48.19056  0.61%  23.1  141s
#  101369 23838     cutoff   41        48.48627   48.19555  0.60%  23.2  145s
#  104992 24219   48.28715   22  238   48.48627   48.20098  0.59%  23.3  150s
#  110389 24581     cutoff   36        48.48627   48.20739  0.58%  23.4  157s
#  113601 24820     cutoff   24        48.48627   48.21245  0.56%  23.4  162s
#  117270 25096   48.43815   39  122   48.48627   48.21683  0.56%  23.5  166s
#  120863 25316   48.46001   38  110   48.48627   48.22189  0.55%  23.5  171s
#  123973 25642     cutoff   35        48.48627   48.22568  0.54%  23.6  176s
#  127857 25807   48.34573   33  155   48.48627   48.23078  0.53%  23.6  180s
#  132866 26004     cutoff   27        48.48627   48.23617  0.52%  23.6  187s
#  136621 26084   48.45171   29  134   48.48627   48.24066  0.51%  23.6  191s
#  140143 26140   48.45970   38  119   48.48627   48.24463  0.50%  23.7  196s
#  143849 26190   48.41646   31  119   48.48627   48.24875  0.49%  23.7  200s
#  146417 26191   48.38590   39  128   48.48627   48.25123  0.48%  23.8  206s
#  150154 26193     cutoff   31        48.48627   48.25565  0.48%  23.8  212s
#  152091 26160   48.39445   31  161   48.48627   48.25787  0.47%  23.8  215s
#  155208 26060   48.40228   28  173   48.48627   48.26122  0.46%  23.9  223s
#  157178 26006   48.34490   31  216   48.48627   48.26332  0.46%  23.9  227s
#  159101 25962   48.46982   35  128   48.48627   48.26560  0.46%  23.9  231s
#  162817 25798   48.38142   34  152   48.48627   48.26965  0.45%  24.0  235s
#  166298 25529   48.32189   29  192   48.48627   48.27356  0.44%  24.0  241s
#  170003 25250     cutoff   28        48.48627   48.27801  0.43%  24.1  246s
#  173649 24961     cutoff   36        48.48627   48.28220  0.42%  24.1  251s
#  176843 24688   48.41079   41  130   48.48627   48.28586  0.41%  24.2  256s
#  180371 24284     cutoff   32        48.48627   48.29020  0.40%  24.2  261s
#  184051 23848   48.32086   23  200   48.48627   48.29431  0.40%  24.3  266s
#  187668 23360   48.46096   24  192   48.48627   48.29875  0.39%  24.4  271s
#  189415 23149     cutoff   29        48.48627   48.30047  0.38%  24.4  277s
#  190946 22933     cutoff   34        48.48627   48.30223  0.38%  24.4  280s
#  194940 22478     cutoff   32        48.48627   48.30739  0.37%  24.5  286s
#  195725 22146   48.40032   35  120   48.48627   48.30868  0.37%  24.5  290s
#  197703 21811   48.48422   33  120   48.48627   48.31089  0.36%  24.5  295s
#  201668 21128   48.47250   34  125   48.48627   48.31608  0.35%  24.6  302s
#  203569 20737     cutoff   25        48.48627   48.31803  0.35%  24.6  305s
#  207381 20015     cutoff   32        48.48627   48.32358  0.34%  24.7  313s
#  209194 19593     cutoff   36        48.48627   48.32614  0.33%  24.7  316s
#  211087 19193     cutoff   28        48.48627   48.32875  0.32%  24.8  320s
#  214721 18383   48.44463   38  139   48.48627   48.33409  0.31%  24.8  327s
#  216569 17903     cutoff   26        48.48627   48.33645  0.31%  24.9  330s
#  219766 17074     cutoff   38        48.48627   48.34137  0.30%  24.9  335s
#  223588 15973 infeasible   38        48.48627   48.34765  0.29%  25.0  340s
#  227249 14837   48.47755   34  227   48.48627   48.35420  0.27%  25.1  345s
#  230943 13693     cutoff   37        48.48627   48.36114  0.26%  25.1  350s
#  234240 12219     cutoff   39        48.48627   48.36794  0.24%  25.2  355s
#  238036 10541   48.46610   39   98   48.48627   48.37625  0.23%  25.2  360s
#  241864  8673     cutoff   29        48.48627   48.38590  0.21%  25.3  366s
#  244903  7053     cutoff   33        48.48627   48.39301  0.19%  25.3  371s
#  248882  4506     cutoff   34        48.48627   48.41095  0.16%  25.3  376s
#  250971  2947 infeasible   30        48.48627   48.42098  0.13%  25.2  380s
#
# Cutting planes:
#   Gomory: 23
#   Lift-and-project: 81
#   Cover: 66
#   Implied bound: 1
#   Clique: 2
#   MIR: 102
#   StrongCG: 6
#   Flow cover: 181
#   GUB cover: 4
#   Inf proof: 2
#   Zero half: 111
#   RLT: 20
#
# Explored 256626 nodes (6431216 simplex iterations) in 384.63 seconds (91.16 work units)
# Thread count was 22 (of 22 available processors)
#
# Solution count 10: 48.4863 48.4872 48.4882 ... 48.6114
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.848626591382e+01, best bound 4.848626591382e+01, gap 0.0000%

# %% [markdown]
# ### Print results

# %%
# Define the time range for one week
time_range = range(0, 24 * 7 )  # 7 days, 24 hours each

# Create a DataFrame for the first plot
data_power = pd.DataFrame({
    'Hour': list(time_range),
    'Inflexible Demand': merged_data_summer['Inflexible_Demand_(kWh)'][:len(time_range)],
    'Dishwasher': [power_dishwasher * binary_dishwasher[t].X for t in time_range],
    'Washing Machine': [power_wm * binary_wm[t].X for t in time_range],
    'Dryer': [power_dryer * binary_dryer[t].X for t in time_range],
    'EV Charging': [charging_ev[t].X for t in time_range]
})

# Melt the data for easier plotting
data_power_melted = data_power.melt(id_vars='Hour', var_name='Technology', value_name='Power (kWh)')

# Plot 1: Power demand of all technologies
plt.figure(figsize=(12, 6))
sns.lineplot(data=data_power_melted, x='Hour', y='Power (kWh)', hue='Technology')
plt.title('Power Demand of All Technologies Over 1 Week')
plt.xlabel('Hour')
plt.ylabel('Power (kWh)')
plt.legend(title='Technology')
plt.grid(True)
plt.show()

# Power demand of all technologies
plt.figure(figsize=(10, 6))
ax1 = plt.gca()

# Plot power demand (left y-axis)
sns.lineplot(data=data_power_melted, x='Hour', y='Power (kWh)', hue='Technology', ax=ax1)
ax1.set_xlabel('Hour')
ax1.set_ylabel('Power (kWh)')
ax1.legend(title='Technology', loc='upper left')
ax1.grid(True)

# Create a second y-axis for the price
ax2 = ax1.twinx()
sns.lineplot(
    data=pd.DataFrame({'Hour': list(time_range), 'Price': merged_data_summer['Spotmarket_(EUR/kWh)'][:len(time_range)]}),
    x='Hour', y='Price', color='red', label='Spotmarket Price', linestyle='--', ax=ax2
)
ax2.set_ylabel('Price (EUR/kWh)')

ax3 = ax2.twinx()
sns.lineplot(
    data=pd.DataFrame({'Hour': list(time_range), 'EV SOC': [soc_ev[t].X for t in time_range]}),
    x='Hour', y='EV SOC', color='green', label='EV SOC', linestyle=':', ax=ax3
)
ax3.set_ylabel('EV SOC (kW)')

plt.title('Power Demand, EV and Price')
plt.show()

# %%
#plot demand and demnd level
# Create a DataFrame for the demand and demand level
data_demand = pd.DataFrame({
    'Hour': list(time_range),
    'Total Demand': [total_demand[t].X for t in time_range],
    'Demand Level': [demand_level[t].X for t in time_range]
})
# Melt the data for easier plotting
data_demand_melted = data_demand.melt(id_vars='Hour', var_name='Metric', value_name='Value')
# Plot 2: Total demand and demand level
plt.figure(figsize=(12, 6))
sns.lineplot(data=data_demand_melted, x='Hour', y='Value', hue='Metric')
plt.title('Total Demand and Demand Level Over 1 Week')
plt.xlabel('Hour')
plt.ylabel('Value')
plt.legend(title='Metric')
plt.grid(True)
plt.show()

#plot only total demand
plt.figure(figsize=(12, 6))
sns.lineplot(x=list(time_range), y=[total_demand[t].X for t in time_range], label='Total Demand')
plt.title('Total Demand Over 1 Week')
plt.xlabel('Hour')
plt.ylabel('Total Demand (kWh)')
plt.legend()
plt.grid(True)
plt.show()

# %%
#plot demand levels, demand and penalty costs 
# Create a DataFrame for the demand levels and penalty costs
data_levels = pd.DataFrame({
    'Hour': list(time_range),
    'Demand Level': [demand_level[t].X for t in time_range],
    'Penalty Cost': [penalty_per_level[int(demand_level[t].X)] for t in time_range]
})
# Melt the data for easier plotting
data_levels_melted = data_levels.melt(id_vars='Hour', var_name='Metric', value_name='Value')
# Plot 3: Demand Levels and Penalty Costs
plt.figure(figsize=(12, 6))
sns.lineplot(data=data_levels_melted, x='Hour', y='Value', hue='Metric')
plt.title('Demand Levels and Penalty Costs Over 1 Week')
plt.xlabel('Hour')
plt.ylabel('Value')
plt.legend(title='Metric')
plt.grid(True)
plt.show()

# %%
#print total demand and demand level
print("Total Demand and Demand Level:")
for t in range(Time_interval):
    print(f"Hour {t}: Total Demand = {total_demand[t].X:.2f} kWh, Demand Level = {demand_level[t].X:.2f}")
# Out:
# Total Demand and Demand Level:
# Hour 0: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 1: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 2: Total Demand = 11.58 kWh, Demand Level = 2.00
# Hour 3: Total Demand = 11.58 kWh, Demand Level = 2.00
# Hour 4: Total Demand = 11.58 kWh, Demand Level = 2.00
# Hour 5: Total Demand = 6.08 kWh, Demand Level = 1.00
# Hour 6: Total Demand = 0.10 kWh, Demand Level = 0.00
# Hour 7: Total Demand = 0.81 kWh, Demand Level = 0.00
# Hour 8: Total Demand = 0.47 kWh, Demand Level = 0.00
# Hour 9: Total Demand = 0.11 kWh, Demand Level = 0.00
# Hour 10: Total Demand = 0.11 kWh, Demand Level = 0.00
# Hour 11: Total Demand = 0.13 kWh, Demand Level = 0.00
# Hour 12: Total Demand = 0.20 kWh, Demand Level = 0.00
# Hour 13: Total Demand = 0.24 kWh, Demand Level = 0.00
# Hour 14: Total Demand = 0.17 kWh, Demand Level = 0.00
# Hour 15: Total Demand = 0.15 kWh, Demand Level = 0.00
# Hour 16: Total Demand = 0.14 kWh, Demand Level = 0.00
# Hour 17: Total Demand = 0.51 kWh, Demand Level = 0.00
# Hour 18: Total Demand = 0.15 kWh, Demand Level = 0.00
# Hour 19: Total Demand = 0.63 kWh, Demand Level = 0.00
# Hour 20: Total Demand = 0.36 kWh, Demand Level = 0.00
# Hour 21: Total Demand = 0.17 kWh, Demand Level = 0.00
# Hour 22: Total Demand = 0.14 kWh, Demand Level = 0.00
# Hour 23: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 24: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 25: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 26: Total Demand = 8.25 kWh, Demand Level = 1.00
# Hour 27: Total Demand = 1.58 kWh, Demand Level = 0.00
# Hour 28: Total Demand = 1.58 kWh, Demand Level = 0.00
# Hour 29: Total Demand = 0.09 kWh, Demand Level = 0.00
# Hour 30: Total Demand = 0.47 kWh, Demand Level = 0.00
# Hour 31: Total Demand = 0.95 kWh, Demand Level = 0.00
# Hour 32: Total Demand = 0.17 kWh, Demand Level = 0.00
# Hour 33: Total Demand = 0.11 kWh, Demand Level = 0.00
# Hour 34: Total Demand = 0.12 kWh, Demand Level = 0.00
# Hour 35: Total Demand = 0.13 kWh, Demand Level = 0.00
# Hour 36: Total Demand = 0.15 kWh, Demand Level = 0.00
# Hour 37: Total Demand = 0.17 kWh, Demand Level = 0.00
# Hour 38: Total Demand = 0.19 kWh, Demand Level = 0.00
# Hour 39: Total Demand = 0.12 kWh, Demand Level = 0.00
# Hour 40: Total Demand = 0.11 kWh, Demand Level = 0.00
# Hour 41: Total Demand = 0.11 kWh, Demand Level = 0.00
# Hour 42: Total Demand = 0.30 kWh, Demand Level = 0.00
# Hour 43: Total Demand = 0.19 kWh, Demand Level = 0.00
# Hour 44: Total Demand = 0.16 kWh, Demand Level = 0.00
# Hour 45: Total Demand = 0.14 kWh, Demand Level = 0.00
# Hour 46: Total Demand = 0.14 kWh, Demand Level = 0.00
# Hour 47: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 48: Total Demand = 1.58 kWh, Demand Level = 0.00
# Hour 49: Total Demand = 5.58 kWh, Demand Level = 1.00
# Hour 50: Total Demand = 11.58 kWh, Demand Level = 2.00
# Hour 51: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 52: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 53: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 54: Total Demand = 0.54 kWh, Demand Level = 0.00
# Hour 55: Total Demand = 0.67 kWh, Demand Level = 0.00
# Hour 56: Total Demand = 0.24 kWh, Demand Level = 0.00
# Hour 57: Total Demand = 0.12 kWh, Demand Level = 0.00
# Hour 58: Total Demand = 0.13 kWh, Demand Level = 0.00
# Hour 59: Total Demand = 0.18 kWh, Demand Level = 0.00
# Hour 60: Total Demand = 0.15 kWh, Demand Level = 0.00
# Hour 61: Total Demand = 0.12 kWh, Demand Level = 0.00
# Hour 62: Total Demand = 0.12 kWh, Demand Level = 0.00
# Hour 63: Total Demand = 0.10 kWh, Demand Level = 0.00
# Hour 64: Total Demand = 0.14 kWh, Demand Level = 0.00
# Hour 65: Total Demand = 0.11 kWh, Demand Level = 0.00
# Hour 66: Total Demand = 0.92 kWh, Demand Level = 0.00
# Hour 67: Total Demand = 0.66 kWh, Demand Level = 0.00
# Hour 68: Total Demand = 0.17 kWh, Demand Level = 0.00
# Hour 69: Total Demand = 0.27 kWh, Demand Level = 0.00
# Hour 70: Total Demand = 0.20 kWh, Demand Level = 0.00
# Hour 71: Total Demand = 0.07 kWh, Demand Level = 0.00
# Hour 72: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 73: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 74: Total Demand = 1.58 kWh, Demand Level = 0.00
# Hour 75: Total Demand = 1.58 kWh, Demand Level = 0.00
# Hour 76: Total Demand = 1.58 kWh, Demand Level = 0.00
# Hour 77: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 78: Total Demand = 0.59 kWh, Demand Level = 0.00
# Hour 79: Total Demand = 0.30 kWh, Demand Level = 0.00
# Hour 80: Total Demand = 0.57 kWh, Demand Level = 0.00
# Hour 81: Total Demand = 0.14 kWh, Demand Level = 0.00
# Hour 82: Total Demand = 0.12 kWh, Demand Level = 0.00
# Hour 83: Total Demand = 0.16 kWh, Demand Level = 0.00
# Hour 84: Total Demand = 0.23 kWh, Demand Level = 0.00
# Hour 85: Total Demand = 0.18 kWh, Demand Level = 0.00
# Hour 86: Total Demand = 0.12 kWh, Demand Level = 0.00
# Hour 87: Total Demand = 0.13 kWh, Demand Level = 0.00
# Hour 88: Total Demand = 0.11 kWh, Demand Level = 0.00
# Hour 89: Total Demand = 0.10 kWh, Demand Level = 0.00
# Hour 90: Total Demand = 0.24 kWh, Demand Level = 0.00
# Hour 91: Total Demand = 2.17 kWh, Demand Level = 0.00
# Hour 92: Total Demand = 2.17 kWh, Demand Level = 0.00
# Hour 93: Total Demand = 2.23 kWh, Demand Level = 0.00
# Hour 94: Total Demand = 0.15 kWh, Demand Level = 0.00
# Hour 95: Total Demand = 0.09 kWh, Demand Level = 0.00
# Hour 96: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 97: Total Demand = 0.07 kWh, Demand Level = 0.00
# Hour 98: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 99: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 100: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 101: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 102: Total Demand = 0.10 kWh, Demand Level = 0.00
# Hour 103: Total Demand = 0.77 kWh, Demand Level = 0.00
# Hour 104: Total Demand = 0.61 kWh, Demand Level = 0.00
# Hour 105: Total Demand = 0.60 kWh, Demand Level = 0.00
# Hour 106: Total Demand = 0.43 kWh, Demand Level = 0.00
# Hour 107: Total Demand = 0.19 kWh, Demand Level = 0.00
# Hour 108: Total Demand = 3.13 kWh, Demand Level = 0.00
# Hour 109: Total Demand = 4.62 kWh, Demand Level = 0.00
# Hour 110: Total Demand = 11.88 kWh, Demand Level = 2.00
# Hour 111: Total Demand = 4.82 kWh, Demand Level = 0.00
# Hour 112: Total Demand = 0.13 kWh, Demand Level = 0.00
# Hour 113: Total Demand = 0.14 kWh, Demand Level = 0.00
# Hour 114: Total Demand = 0.21 kWh, Demand Level = 0.00
# Hour 115: Total Demand = 0.57 kWh, Demand Level = 0.00
# Hour 116: Total Demand = 0.40 kWh, Demand Level = 0.00
# Hour 117: Total Demand = 0.15 kWh, Demand Level = 0.00
# Hour 118: Total Demand = 0.17 kWh, Demand Level = 0.00
# Hour 119: Total Demand = 0.10 kWh, Demand Level = 0.00
# Hour 120: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 121: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 122: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 123: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 124: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 125: Total Demand = 0.07 kWh, Demand Level = 0.00
# Hour 126: Total Demand = 0.79 kWh, Demand Level = 0.00
# Hour 127: Total Demand = 0.35 kWh, Demand Level = 0.00
# Hour 128: Total Demand = 3.97 kWh, Demand Level = 0.00
# Hour 129: Total Demand = 3.17 kWh, Demand Level = 0.00
# Hour 130: Total Demand = 3.80 kWh, Demand Level = 0.00
# Hour 131: Total Demand = 6.92 kWh, Demand Level = 1.00
# Hour 132: Total Demand = 3.24 kWh, Demand Level = 0.00
# Hour 133: Total Demand = 5.89 kWh, Demand Level = 1.00
# Hour 134: Total Demand = 17.63 kWh, Demand Level = 2.00
# Hour 135: Total Demand = 9.64 kWh, Demand Level = 1.00
# Hour 136: Total Demand = 3.17 kWh, Demand Level = 0.00
# Hour 137: Total Demand = 3.14 kWh, Demand Level = 0.00
# Hour 138: Total Demand = 2.13 kWh, Demand Level = 0.00
# Hour 139: Total Demand = 0.91 kWh, Demand Level = 0.00
# Hour 140: Total Demand = 0.29 kWh, Demand Level = 0.00
# Hour 141: Total Demand = 0.33 kWh, Demand Level = 0.00
# Hour 142: Total Demand = 0.21 kWh, Demand Level = 0.00
# Hour 143: Total Demand = 0.13 kWh, Demand Level = 0.00
# Hour 144: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 145: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 146: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 147: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 148: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 149: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 150: Total Demand = 0.25 kWh, Demand Level = 0.00
# Hour 151: Total Demand = 0.64 kWh, Demand Level = 0.00
# Hour 152: Total Demand = 0.60 kWh, Demand Level = 0.00
# Hour 153: Total Demand = 0.74 kWh, Demand Level = 0.00
# Hour 154: Total Demand = 0.18 kWh, Demand Level = 0.00
# Hour 155: Total Demand = 0.17 kWh, Demand Level = 0.00
# Hour 156: Total Demand = 1.64 kWh, Demand Level = 0.00
# Hour 157: Total Demand = 1.63 kWh, Demand Level = 0.00
# Hour 158: Total Demand = 1.62 kWh, Demand Level = 0.00
# Hour 159: Total Demand = 0.15 kWh, Demand Level = 0.00
# Hour 160: Total Demand = 0.19 kWh, Demand Level = 0.00
# Hour 161: Total Demand = 0.10 kWh, Demand Level = 0.00
# Hour 162: Total Demand = 0.11 kWh, Demand Level = 0.00
# Hour 163: Total Demand = 0.13 kWh, Demand Level = 0.00
# Hour 164: Total Demand = 0.50 kWh, Demand Level = 0.00
# Hour 165: Total Demand = 0.20 kWh, Demand Level = 0.00
# Hour 166: Total Demand = 0.13 kWh, Demand Level = 0.00
# Hour 167: Total Demand = 0.07 kWh, Demand Level = 0.00
# Hour 168: Total Demand = 0.07 kWh, Demand Level = 0.00
# Hour 169: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 170: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 171: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 172: Total Demand = 2.30 kWh, Demand Level = 0.00
# Hour 173: Total Demand = 0.09 kWh, Demand Level = 0.00
# Hour 174: Total Demand = 0.43 kWh, Demand Level = 0.00
# Hour 175: Total Demand = 0.38 kWh, Demand Level = 0.00
# Hour 176: Total Demand = 0.71 kWh, Demand Level = 0.00
# Hour 177: Total Demand = 0.12 kWh, Demand Level = 0.00
# Hour 178: Total Demand = 0.16 kWh, Demand Level = 0.00
# Hour 179: Total Demand = 0.16 kWh, Demand Level = 0.00
# Hour 180: Total Demand = 0.16 kWh, Demand Level = 0.00
# Hour 181: Total Demand = 0.15 kWh, Demand Level = 0.00
# Hour 182: Total Demand = 1.64 kWh, Demand Level = 0.00
# Hour 183: Total Demand = 1.64 kWh, Demand Level = 0.00
# Hour 184: Total Demand = 1.60 kWh, Demand Level = 0.00
# Hour 185: Total Demand = 0.11 kWh, Demand Level = 0.00
# Hour 186: Total Demand = 0.61 kWh, Demand Level = 0.00
# Hour 187: Total Demand = 0.18 kWh, Demand Level = 0.00
# Hour 188: Total Demand = 0.26 kWh, Demand Level = 0.00
# Hour 189: Total Demand = 0.19 kWh, Demand Level = 0.00
# Hour 190: Total Demand = 0.14 kWh, Demand Level = 0.00
# Hour 191: Total Demand = 0.07 kWh, Demand Level = 0.00
# Hour 192: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 193: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 194: Total Demand = 0.07 kWh, Demand Level = 0.00
# Hour 195: Total Demand = 0.07 kWh, Demand Level = 0.00
# Hour 196: Total Demand = 0.07 kWh, Demand Level = 0.00
# Hour 197: Total Demand = 0.10 kWh, Demand Level = 0.00
# Hour 198: Total Demand = 0.45 kWh, Demand Level = 0.00
# Hour 199: Total Demand = 0.32 kWh, Demand Level = 0.00
# Hour 200: Total Demand = 0.11 kWh, Demand Level = 0.00
# Hour 201: Total Demand = 0.10 kWh, Demand Level = 0.00
# Hour 202: Total Demand = 0.16 kWh, Demand Level = 0.00
# Hour 203: Total Demand = 0.24 kWh, Demand Level = 0.00
# Hour 204: Total Demand = 0.20 kWh, Demand Level = 0.00
# Hour 205: Total Demand = 1.62 kWh, Demand Level = 0.00
# Hour 206: Total Demand = 4.26 kWh, Demand Level = 0.00
# Hour 207: Total Demand = 1.60 kWh, Demand Level = 0.00
# Hour 208: Total Demand = 0.14 kWh, Demand Level = 0.00
# Hour 209: Total Demand = 0.75 kWh, Demand Level = 0.00
# Hour 210: Total Demand = 0.48 kWh, Demand Level = 0.00
# Hour 211: Total Demand = 1.15 kWh, Demand Level = 0.00
# Hour 212: Total Demand = 2.62 kWh, Demand Level = 0.00
# Hour 213: Total Demand = 1.90 kWh, Demand Level = 0.00
# Hour 214: Total Demand = 0.17 kWh, Demand Level = 0.00
# Hour 215: Total Demand = 0.13 kWh, Demand Level = 0.00
# Hour 216: Total Demand = 0.07 kWh, Demand Level = 0.00
# Hour 217: Total Demand = 0.07 kWh, Demand Level = 0.00
# Hour 218: Total Demand = 0.07 kWh, Demand Level = 0.00
# Hour 219: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 220: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 221: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 222: Total Demand = 0.12 kWh, Demand Level = 0.00
# Hour 223: Total Demand = 0.47 kWh, Demand Level = 0.00
# Hour 224: Total Demand = 0.44 kWh, Demand Level = 0.00
# Hour 225: Total Demand = 0.10 kWh, Demand Level = 0.00
# Hour 226: Total Demand = 0.10 kWh, Demand Level = 0.00
# Hour 227: Total Demand = 0.17 kWh, Demand Level = 0.00
# Hour 228: Total Demand = 0.17 kWh, Demand Level = 0.00
# Hour 229: Total Demand = 1.65 kWh, Demand Level = 0.00
# Hour 230: Total Demand = 1.66 kWh, Demand Level = 0.00
# Hour 231: Total Demand = 1.65 kWh, Demand Level = 0.00
# Hour 232: Total Demand = 0.12 kWh, Demand Level = 0.00
# Hour 233: Total Demand = 0.20 kWh, Demand Level = 0.00
# Hour 234: Total Demand = 0.31 kWh, Demand Level = 0.00
# Hour 235: Total Demand = 0.99 kWh, Demand Level = 0.00
# Hour 236: Total Demand = 0.18 kWh, Demand Level = 0.00
# Hour 237: Total Demand = 0.17 kWh, Demand Level = 0.00
# Hour 238: Total Demand = 0.16 kWh, Demand Level = 0.00
# Hour 239: Total Demand = 0.09 kWh, Demand Level = 0.00
# Hour 240: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 241: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 242: Total Demand = 0.07 kWh, Demand Level = 0.00
# Hour 243: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 244: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 245: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 246: Total Demand = 0.32 kWh, Demand Level = 0.00
# Hour 247: Total Demand = 0.94 kWh, Demand Level = 0.00
# Hour 248: Total Demand = 0.39 kWh, Demand Level = 0.00
# Hour 249: Total Demand = 0.25 kWh, Demand Level = 0.00
# Hour 250: Total Demand = 0.17 kWh, Demand Level = 0.00
# Hour 251: Total Demand = 0.11 kWh, Demand Level = 0.00
# Hour 252: Total Demand = 1.60 kWh, Demand Level = 0.00
# Hour 253: Total Demand = 1.62 kWh, Demand Level = 0.00
# Hour 254: Total Demand = 3.86 kWh, Demand Level = 0.00
# Hour 255: Total Demand = 0.12 kWh, Demand Level = 0.00
# Hour 256: Total Demand = 0.11 kWh, Demand Level = 0.00
# Hour 257: Total Demand = 0.14 kWh, Demand Level = 0.00
# Hour 258: Total Demand = 0.18 kWh, Demand Level = 0.00
# Hour 259: Total Demand = 1.55 kWh, Demand Level = 0.00
# Hour 260: Total Demand = 0.67 kWh, Demand Level = 0.00
# Hour 261: Total Demand = 0.15 kWh, Demand Level = 0.00
# Hour 262: Total Demand = 0.27 kWh, Demand Level = 0.00
# Hour 263: Total Demand = 0.16 kWh, Demand Level = 0.00
# Hour 264: Total Demand = 0.07 kWh, Demand Level = 0.00
# Hour 265: Total Demand = 0.07 kWh, Demand Level = 0.00
# Hour 266: Total Demand = 0.09 kWh, Demand Level = 0.00
# Hour 267: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 268: Total Demand = 0.07 kWh, Demand Level = 0.00
# Hour 269: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 270: Total Demand = 0.10 kWh, Demand Level = 0.00
# Hour 271: Total Demand = 0.51 kWh, Demand Level = 0.00
# Hour 272: Total Demand = 0.42 kWh, Demand Level = 0.00
# Hour 273: Total Demand = 0.58 kWh, Demand Level = 0.00
# Hour 274: Total Demand = 0.72 kWh, Demand Level = 0.00
# Hour 275: Total Demand = 4.40 kWh, Demand Level = 0.00
# Hour 276: Total Demand = 3.21 kWh, Demand Level = 0.00
# Hour 277: Total Demand = 4.64 kWh, Demand Level = 0.00
# Hour 278: Total Demand = 15.11 kWh, Demand Level = 2.00
# Hour 279: Total Demand = 5.99 kWh, Demand Level = 1.00
# Hour 280: Total Demand = 3.12 kWh, Demand Level = 0.00
# Hour 281: Total Demand = 3.11 kWh, Demand Level = 0.00
# Hour 282: Total Demand = 0.15 kWh, Demand Level = 0.00
# Hour 283: Total Demand = 1.04 kWh, Demand Level = 0.00
# Hour 284: Total Demand = 0.17 kWh, Demand Level = 0.00
# Hour 285: Total Demand = 0.15 kWh, Demand Level = 0.00
# Hour 286: Total Demand = 0.18 kWh, Demand Level = 0.00
# Hour 287: Total Demand = 0.17 kWh, Demand Level = 0.00
# Hour 288: Total Demand = 0.11 kWh, Demand Level = 0.00
# Hour 289: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 290: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 291: Total Demand = 0.07 kWh, Demand Level = 0.00
# Hour 292: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 293: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 294: Total Demand = 0.65 kWh, Demand Level = 0.00
# Hour 295: Total Demand = 0.57 kWh, Demand Level = 0.00
# Hour 296: Total Demand = 0.46 kWh, Demand Level = 0.00
# Hour 297: Total Demand = 0.36 kWh, Demand Level = 0.00
# Hour 298: Total Demand = 3.17 kWh, Demand Level = 0.00
# Hour 299: Total Demand = 4.47 kWh, Demand Level = 0.00
# Hour 300: Total Demand = 4.96 kWh, Demand Level = 0.00
# Hour 301: Total Demand = 17.72 kWh, Demand Level = 2.00
# Hour 302: Total Demand = 8.66 kWh, Demand Level = 1.00
# Hour 303: Total Demand = 5.68 kWh, Demand Level = 1.00
# Hour 304: Total Demand = 3.11 kWh, Demand Level = 0.00
# Hour 305: Total Demand = 0.14 kWh, Demand Level = 0.00
# Hour 306: Total Demand = 0.36 kWh, Demand Level = 0.00
# Hour 307: Total Demand = 0.22 kWh, Demand Level = 0.00
# Hour 308: Total Demand = 0.15 kWh, Demand Level = 0.00
# Hour 309: Total Demand = 0.70 kWh, Demand Level = 0.00
# Hour 310: Total Demand = 0.14 kWh, Demand Level = 0.00
# Hour 311: Total Demand = 0.12 kWh, Demand Level = 0.00
# Hour 312: Total Demand = 0.09 kWh, Demand Level = 0.00
# Hour 313: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 314: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 315: Total Demand = 0.07 kWh, Demand Level = 0.00
# Hour 316: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 317: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 318: Total Demand = 0.76 kWh, Demand Level = 0.00
# Hour 319: Total Demand = 0.11 kWh, Demand Level = 0.00
# Hour 320: Total Demand = 0.58 kWh, Demand Level = 0.00
# Hour 321: Total Demand = 0.10 kWh, Demand Level = 0.00
# Hour 322: Total Demand = 0.12 kWh, Demand Level = 0.00
# Hour 323: Total Demand = 0.19 kWh, Demand Level = 0.00
# Hour 324: Total Demand = 1.71 kWh, Demand Level = 0.00
# Hour 325: Total Demand = 1.62 kWh, Demand Level = 0.00
# Hour 326: Total Demand = 1.62 kWh, Demand Level = 0.00
# Hour 327: Total Demand = 0.16 kWh, Demand Level = 0.00
# Hour 328: Total Demand = 0.20 kWh, Demand Level = 0.00
# Hour 329: Total Demand = 0.20 kWh, Demand Level = 0.00
# Hour 330: Total Demand = 0.29 kWh, Demand Level = 0.00
# Hour 331: Total Demand = 0.26 kWh, Demand Level = 0.00
# Hour 332: Total Demand = 0.18 kWh, Demand Level = 0.00
# Hour 333: Total Demand = 0.18 kWh, Demand Level = 0.00
# Hour 334: Total Demand = 0.13 kWh, Demand Level = 0.00
# Hour 335: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 336: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 337: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 338: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 339: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 340: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 341: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 342: Total Demand = 0.60 kWh, Demand Level = 0.00
# Hour 343: Total Demand = 0.30 kWh, Demand Level = 0.00
# Hour 344: Total Demand = 0.13 kWh, Demand Level = 0.00
# Hour 345: Total Demand = 0.16 kWh, Demand Level = 0.00
# Hour 346: Total Demand = 0.23 kWh, Demand Level = 0.00
# Hour 347: Total Demand = 0.15 kWh, Demand Level = 0.00
# Hour 348: Total Demand = 0.11 kWh, Demand Level = 0.00
# Hour 349: Total Demand = 1.75 kWh, Demand Level = 0.00
# Hour 350: Total Demand = 1.62 kWh, Demand Level = 0.00
# Hour 351: Total Demand = 1.62 kWh, Demand Level = 0.00
# Hour 352: Total Demand = 0.12 kWh, Demand Level = 0.00
# Hour 353: Total Demand = 0.60 kWh, Demand Level = 0.00
# Hour 354: Total Demand = 0.99 kWh, Demand Level = 0.00
# Hour 355: Total Demand = 0.33 kWh, Demand Level = 0.00
# Hour 356: Total Demand = 0.27 kWh, Demand Level = 0.00
# Hour 357: Total Demand = 0.19 kWh, Demand Level = 0.00
# Hour 358: Total Demand = 0.14 kWh, Demand Level = 0.00
# Hour 359: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 360: Total Demand = 0.07 kWh, Demand Level = 0.00
# Hour 361: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 362: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 363: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 364: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 365: Total Demand = 0.09 kWh, Demand Level = 0.00
# Hour 366: Total Demand = 0.10 kWh, Demand Level = 0.00
# Hour 367: Total Demand = 0.67 kWh, Demand Level = 0.00
# Hour 368: Total Demand = 0.79 kWh, Demand Level = 0.00
# Hour 369: Total Demand = 0.15 kWh, Demand Level = 0.00
# Hour 370: Total Demand = 0.17 kWh, Demand Level = 0.00
# Hour 371: Total Demand = 0.16 kWh, Demand Level = 0.00
# Hour 372: Total Demand = 0.27 kWh, Demand Level = 0.00
# Hour 373: Total Demand = 1.60 kWh, Demand Level = 0.00
# Hour 374: Total Demand = 6.49 kWh, Demand Level = 1.00
# Hour 375: Total Demand = 1.62 kWh, Demand Level = 0.00
# Hour 376: Total Demand = 0.12 kWh, Demand Level = 0.00
# Hour 377: Total Demand = 0.12 kWh, Demand Level = 0.00
# Hour 378: Total Demand = 0.15 kWh, Demand Level = 0.00
# Hour 379: Total Demand = 0.53 kWh, Demand Level = 0.00
# Hour 380: Total Demand = 0.16 kWh, Demand Level = 0.00
# Hour 381: Total Demand = 0.15 kWh, Demand Level = 0.00
# Hour 382: Total Demand = 0.16 kWh, Demand Level = 0.00
# Hour 383: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 384: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 385: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 386: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 387: Total Demand = 0.07 kWh, Demand Level = 0.00
# Hour 388: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 389: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 390: Total Demand = 0.27 kWh, Demand Level = 0.00
# Hour 391: Total Demand = 0.53 kWh, Demand Level = 0.00
# Hour 392: Total Demand = 0.21 kWh, Demand Level = 0.00
# Hour 393: Total Demand = 0.27 kWh, Demand Level = 0.00
# Hour 394: Total Demand = 0.12 kWh, Demand Level = 0.00
# Hour 395: Total Demand = 0.11 kWh, Demand Level = 0.00
# Hour 396: Total Demand = 0.10 kWh, Demand Level = 0.00
# Hour 397: Total Demand = 1.62 kWh, Demand Level = 0.00
# Hour 398: Total Demand = 1.61 kWh, Demand Level = 0.00
# Hour 399: Total Demand = 1.60 kWh, Demand Level = 0.00
# Hour 400: Total Demand = 0.13 kWh, Demand Level = 0.00
# Hour 401: Total Demand = 0.15 kWh, Demand Level = 0.00
# Hour 402: Total Demand = 2.59 kWh, Demand Level = 0.00
# Hour 403: Total Demand = 0.75 kWh, Demand Level = 0.00
# Hour 404: Total Demand = 0.26 kWh, Demand Level = 0.00
# Hour 405: Total Demand = 0.21 kWh, Demand Level = 0.00
# Hour 406: Total Demand = 0.15 kWh, Demand Level = 0.00
# Hour 407: Total Demand = 0.11 kWh, Demand Level = 0.00
# Hour 408: Total Demand = 0.11 kWh, Demand Level = 0.00
# Hour 409: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 410: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 411: Total Demand = 0.07 kWh, Demand Level = 0.00
# Hour 412: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 413: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 414: Total Demand = 0.10 kWh, Demand Level = 0.00
# Hour 415: Total Demand = 0.77 kWh, Demand Level = 0.00
# Hour 416: Total Demand = 0.11 kWh, Demand Level = 0.00
# Hour 417: Total Demand = 0.12 kWh, Demand Level = 0.00
# Hour 418: Total Demand = 0.31 kWh, Demand Level = 0.00
# Hour 419: Total Demand = 0.23 kWh, Demand Level = 0.00
# Hour 420: Total Demand = 1.67 kWh, Demand Level = 0.00
# Hour 421: Total Demand = 1.62 kWh, Demand Level = 0.00
# Hour 422: Total Demand = 3.83 kWh, Demand Level = 0.00
# Hour 423: Total Demand = 0.11 kWh, Demand Level = 0.00
# Hour 424: Total Demand = 0.11 kWh, Demand Level = 0.00
# Hour 425: Total Demand = 0.12 kWh, Demand Level = 0.00
# Hour 426: Total Demand = 1.57 kWh, Demand Level = 0.00
# Hour 427: Total Demand = 2.46 kWh, Demand Level = 0.00
# Hour 428: Total Demand = 1.46 kWh, Demand Level = 0.00
# Hour 429: Total Demand = 0.20 kWh, Demand Level = 0.00
# Hour 430: Total Demand = 0.13 kWh, Demand Level = 0.00
# Hour 431: Total Demand = 0.07 kWh, Demand Level = 0.00
# Hour 432: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 433: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 434: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 435: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 436: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 437: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 438: Total Demand = 0.76 kWh, Demand Level = 0.00
# Hour 439: Total Demand = 0.18 kWh, Demand Level = 0.00
# Hour 440: Total Demand = 0.75 kWh, Demand Level = 0.00
# Hour 441: Total Demand = 0.27 kWh, Demand Level = 0.00
# Hour 442: Total Demand = 3.29 kWh, Demand Level = 0.00
# Hour 443: Total Demand = 3.51 kWh, Demand Level = 0.00
# Hour 444: Total Demand = 3.17 kWh, Demand Level = 0.00
# Hour 445: Total Demand = 7.65 kWh, Demand Level = 1.00
# Hour 446: Total Demand = 12.11 kWh, Demand Level = 2.00
# Hour 447: Total Demand = 6.22 kWh, Demand Level = 1.00
# Hour 448: Total Demand = 3.32 kWh, Demand Level = 0.00
# Hour 449: Total Demand = 0.14 kWh, Demand Level = 0.00
# Hour 450: Total Demand = 1.52 kWh, Demand Level = 0.00
# Hour 451: Total Demand = 1.32 kWh, Demand Level = 0.00
# Hour 452: Total Demand = 0.19 kWh, Demand Level = 0.00
# Hour 453: Total Demand = 0.15 kWh, Demand Level = 0.00
# Hour 454: Total Demand = 0.11 kWh, Demand Level = 0.00
# Hour 455: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 456: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 457: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 458: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 459: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 460: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 461: Total Demand = 0.09 kWh, Demand Level = 0.00
# Hour 462: Total Demand = 0.34 kWh, Demand Level = 0.00
# Hour 463: Total Demand = 0.51 kWh, Demand Level = 0.00
# Hour 464: Total Demand = 0.51 kWh, Demand Level = 0.00
# Hour 465: Total Demand = 0.31 kWh, Demand Level = 0.00
# Hour 466: Total Demand = 3.17 kWh, Demand Level = 0.00
# Hour 467: Total Demand = 4.17 kWh, Demand Level = 0.00
# Hour 468: Total Demand = 4.66 kWh, Demand Level = 0.00
# Hour 469: Total Demand = 17.66 kWh, Demand Level = 2.00
# Hour 470: Total Demand = 8.88 kWh, Demand Level = 1.00
# Hour 471: Total Demand = 6.03 kWh, Demand Level = 1.00
# Hour 472: Total Demand = 3.10 kWh, Demand Level = 0.00
# Hour 473: Total Demand = 0.14 kWh, Demand Level = 0.00
# Hour 474: Total Demand = 0.17 kWh, Demand Level = 0.00
# Hour 475: Total Demand = 0.18 kWh, Demand Level = 0.00
# Hour 476: Total Demand = 0.16 kWh, Demand Level = 0.00
# Hour 477: Total Demand = 2.43 kWh, Demand Level = 0.00
# Hour 478: Total Demand = 0.68 kWh, Demand Level = 0.00
# Hour 479: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 480: Total Demand = 0.07 kWh, Demand Level = 0.00
# Hour 481: Total Demand = 0.07 kWh, Demand Level = 0.00
# Hour 482: Total Demand = 0.07 kWh, Demand Level = 0.00
# Hour 483: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 484: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 485: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 486: Total Demand = 0.68 kWh, Demand Level = 0.00
# Hour 487: Total Demand = 0.14 kWh, Demand Level = 0.00
# Hour 488: Total Demand = 0.15 kWh, Demand Level = 0.00
# Hour 489: Total Demand = 0.11 kWh, Demand Level = 0.00
# Hour 490: Total Demand = 0.13 kWh, Demand Level = 0.00
# Hour 491: Total Demand = 0.16 kWh, Demand Level = 0.00
# Hour 492: Total Demand = 1.66 kWh, Demand Level = 0.00
# Hour 493: Total Demand = 1.65 kWh, Demand Level = 0.00
# Hour 494: Total Demand = 1.66 kWh, Demand Level = 0.00
# Hour 495: Total Demand = 0.12 kWh, Demand Level = 0.00
# Hour 496: Total Demand = 0.15 kWh, Demand Level = 0.00
# Hour 497: Total Demand = 0.17 kWh, Demand Level = 0.00
# Hour 498: Total Demand = 0.28 kWh, Demand Level = 0.00
# Hour 499: Total Demand = 0.16 kWh, Demand Level = 0.00
# Hour 500: Total Demand = 0.55 kWh, Demand Level = 0.00
# Hour 501: Total Demand = 0.16 kWh, Demand Level = 0.00
# Hour 502: Total Demand = 0.16 kWh, Demand Level = 0.00
# Hour 503: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 504: Total Demand = 0.07 kWh, Demand Level = 0.00
# Hour 505: Total Demand = 0.07 kWh, Demand Level = 0.00
# Hour 506: Total Demand = 0.07 kWh, Demand Level = 0.00
# Hour 507: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 508: Total Demand = 0.09 kWh, Demand Level = 0.00
# Hour 509: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 510: Total Demand = 0.57 kWh, Demand Level = 0.00
# Hour 511: Total Demand = 0.86 kWh, Demand Level = 0.00
# Hour 512: Total Demand = 0.14 kWh, Demand Level = 0.00
# Hour 513: Total Demand = 0.13 kWh, Demand Level = 0.00
# Hour 514: Total Demand = 0.11 kWh, Demand Level = 0.00
# Hour 515: Total Demand = 0.12 kWh, Demand Level = 0.00
# Hour 516: Total Demand = 1.62 kWh, Demand Level = 0.00
# Hour 517: Total Demand = 1.61 kWh, Demand Level = 0.00
# Hour 518: Total Demand = 1.62 kWh, Demand Level = 0.00
# Hour 519: Total Demand = 0.12 kWh, Demand Level = 0.00
# Hour 520: Total Demand = 0.18 kWh, Demand Level = 0.00
# Hour 521: Total Demand = 0.25 kWh, Demand Level = 0.00
# Hour 522: Total Demand = 0.17 kWh, Demand Level = 0.00
# Hour 523: Total Demand = 0.27 kWh, Demand Level = 0.00
# Hour 524: Total Demand = 0.60 kWh, Demand Level = 0.00
# Hour 525: Total Demand = 0.37 kWh, Demand Level = 0.00
# Hour 526: Total Demand = 0.19 kWh, Demand Level = 0.00
# Hour 527: Total Demand = 0.14 kWh, Demand Level = 0.00
# Hour 528: Total Demand = 0.07 kWh, Demand Level = 0.00
# Hour 529: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 530: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 531: Total Demand = 0.07 kWh, Demand Level = 0.00
# Hour 532: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 533: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 534: Total Demand = 0.12 kWh, Demand Level = 0.00
# Hour 535: Total Demand = 0.36 kWh, Demand Level = 0.00
# Hour 536: Total Demand = 0.37 kWh, Demand Level = 0.00
# Hour 537: Total Demand = 0.10 kWh, Demand Level = 0.00
# Hour 538: Total Demand = 0.11 kWh, Demand Level = 0.00
# Hour 539: Total Demand = 1.62 kWh, Demand Level = 0.00
# Hour 540: Total Demand = 1.60 kWh, Demand Level = 0.00
# Hour 541: Total Demand = 1.65 kWh, Demand Level = 0.00
# Hour 542: Total Demand = 0.12 kWh, Demand Level = 0.00
# Hour 543: Total Demand = 0.11 kWh, Demand Level = 0.00
# Hour 544: Total Demand = 0.10 kWh, Demand Level = 0.00
# Hour 545: Total Demand = 0.10 kWh, Demand Level = 0.00
# Hour 546: Total Demand = 0.41 kWh, Demand Level = 0.00
# Hour 547: Total Demand = 1.47 kWh, Demand Level = 0.00
# Hour 548: Total Demand = 0.20 kWh, Demand Level = 0.00
# Hour 549: Total Demand = 0.18 kWh, Demand Level = 0.00
# Hour 550: Total Demand = 0.15 kWh, Demand Level = 0.00
# Hour 551: Total Demand = 0.10 kWh, Demand Level = 0.00
# Hour 552: Total Demand = 0.07 kWh, Demand Level = 0.00
# Hour 553: Total Demand = 0.07 kWh, Demand Level = 0.00
# Hour 554: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 555: Total Demand = 1.58 kWh, Demand Level = 0.00
# Hour 556: Total Demand = 1.57 kWh, Demand Level = 0.00
# Hour 557: Total Demand = 1.57 kWh, Demand Level = 0.00
# Hour 558: Total Demand = 0.43 kWh, Demand Level = 0.00
# Hour 559: Total Demand = 0.59 kWh, Demand Level = 0.00
# Hour 560: Total Demand = 0.77 kWh, Demand Level = 0.00
# Hour 561: Total Demand = 0.10 kWh, Demand Level = 0.00
# Hour 562: Total Demand = 0.10 kWh, Demand Level = 0.00
# Hour 563: Total Demand = 0.10 kWh, Demand Level = 0.00
# Hour 564: Total Demand = 0.12 kWh, Demand Level = 0.00
# Hour 565: Total Demand = 0.12 kWh, Demand Level = 0.00
# Hour 566: Total Demand = 0.15 kWh, Demand Level = 0.00
# Hour 567: Total Demand = 0.16 kWh, Demand Level = 0.00
# Hour 568: Total Demand = 0.13 kWh, Demand Level = 0.00
# Hour 569: Total Demand = 0.12 kWh, Demand Level = 0.00
# Hour 570: Total Demand = 0.13 kWh, Demand Level = 0.00
# Hour 571: Total Demand = 0.18 kWh, Demand Level = 0.00
# Hour 572: Total Demand = 3.04 kWh, Demand Level = 0.00
# Hour 573: Total Demand = 3.74 kWh, Demand Level = 0.00
# Hour 574: Total Demand = 0.40 kWh, Demand Level = 0.00
# Hour 575: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 576: Total Demand = 0.07 kWh, Demand Level = 0.00
# Hour 577: Total Demand = 0.07 kWh, Demand Level = 0.00
# Hour 578: Total Demand = 1.57 kWh, Demand Level = 0.00
# Hour 579: Total Demand = 1.58 kWh, Demand Level = 0.00
# Hour 580: Total Demand = 6.46 kWh, Demand Level = 1.00
# Hour 581: Total Demand = 0.07 kWh, Demand Level = 0.00
# Hour 582: Total Demand = 0.58 kWh, Demand Level = 0.00
# Hour 583: Total Demand = 0.85 kWh, Demand Level = 0.00
# Hour 584: Total Demand = 0.17 kWh, Demand Level = 0.00
# Hour 585: Total Demand = 0.10 kWh, Demand Level = 0.00
# Hour 586: Total Demand = 0.10 kWh, Demand Level = 0.00
# Hour 587: Total Demand = 0.12 kWh, Demand Level = 0.00
# Hour 588: Total Demand = 0.14 kWh, Demand Level = 0.00
# Hour 589: Total Demand = 0.10 kWh, Demand Level = 0.00
# Hour 590: Total Demand = 0.11 kWh, Demand Level = 0.00
# Hour 591: Total Demand = 0.12 kWh, Demand Level = 0.00
# Hour 592: Total Demand = 0.33 kWh, Demand Level = 0.00
# Hour 593: Total Demand = 0.43 kWh, Demand Level = 0.00
# Hour 594: Total Demand = 0.51 kWh, Demand Level = 0.00
# Hour 595: Total Demand = 0.15 kWh, Demand Level = 0.00
# Hour 596: Total Demand = 0.13 kWh, Demand Level = 0.00
# Hour 597: Total Demand = 0.14 kWh, Demand Level = 0.00
# Hour 598: Total Demand = 0.13 kWh, Demand Level = 0.00
# Hour 599: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 600: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 601: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 602: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 603: Total Demand = 0.07 kWh, Demand Level = 0.00
# Hour 604: Total Demand = 2.30 kWh, Demand Level = 0.00
# Hour 605: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 606: Total Demand = 0.18 kWh, Demand Level = 0.00
# Hour 607: Total Demand = 0.59 kWh, Demand Level = 0.00
# Hour 608: Total Demand = 0.64 kWh, Demand Level = 0.00
# Hour 609: Total Demand = 0.67 kWh, Demand Level = 0.00
# Hour 610: Total Demand = 4.34 kWh, Demand Level = 0.00
# Hour 611: Total Demand = 3.17 kWh, Demand Level = 0.00
# Hour 612: Total Demand = 4.74 kWh, Demand Level = 0.00
# Hour 613: Total Demand = 7.70 kWh, Demand Level = 1.00
# Hour 614: Total Demand = 12.11 kWh, Demand Level = 2.00
# Hour 615: Total Demand = 4.55 kWh, Demand Level = 0.00
# Hour 616: Total Demand = 3.19 kWh, Demand Level = 0.00
# Hour 617: Total Demand = 0.39 kWh, Demand Level = 0.00
# Hour 618: Total Demand = 0.69 kWh, Demand Level = 0.00
# Hour 619: Total Demand = 0.20 kWh, Demand Level = 0.00
# Hour 620: Total Demand = 0.20 kWh, Demand Level = 0.00
# Hour 621: Total Demand = 0.19 kWh, Demand Level = 0.00
# Hour 622: Total Demand = 0.17 kWh, Demand Level = 0.00
# Hour 623: Total Demand = 0.07 kWh, Demand Level = 0.00
# Hour 624: Total Demand = 0.07 kWh, Demand Level = 0.00
# Hour 625: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 626: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 627: Total Demand = 0.07 kWh, Demand Level = 0.00
# Hour 628: Total Demand = 0.09 kWh, Demand Level = 0.00
# Hour 629: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 630: Total Demand = 0.30 kWh, Demand Level = 0.00
# Hour 631: Total Demand = 0.80 kWh, Demand Level = 0.00
# Hour 632: Total Demand = 0.26 kWh, Demand Level = 0.00
# Hour 633: Total Demand = 0.72 kWh, Demand Level = 0.00
# Hour 634: Total Demand = 3.18 kWh, Demand Level = 0.00
# Hour 635: Total Demand = 5.34 kWh, Demand Level = 1.00
# Hour 636: Total Demand = 5.68 kWh, Demand Level = 1.00
# Hour 637: Total Demand = 8.74 kWh, Demand Level = 1.00
# Hour 638: Total Demand = 13.19 kWh, Demand Level = 2.00
# Hour 639: Total Demand = 3.15 kWh, Demand Level = 0.00
# Hour 640: Total Demand = 3.25 kWh, Demand Level = 0.00
# Hour 641: Total Demand = 0.19 kWh, Demand Level = 0.00
# Hour 642: Total Demand = 0.15 kWh, Demand Level = 0.00
# Hour 643: Total Demand = 0.30 kWh, Demand Level = 0.00
# Hour 644: Total Demand = 0.20 kWh, Demand Level = 0.00
# Hour 645: Total Demand = 0.14 kWh, Demand Level = 0.00
# Hour 646: Total Demand = 0.12 kWh, Demand Level = 0.00
# Hour 647: Total Demand = 0.07 kWh, Demand Level = 0.00
# Hour 648: Total Demand = 0.09 kWh, Demand Level = 0.00
# Hour 649: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 650: Total Demand = 0.07 kWh, Demand Level = 0.00
# Hour 651: Total Demand = 1.58 kWh, Demand Level = 0.00
# Hour 652: Total Demand = 1.57 kWh, Demand Level = 0.00
# Hour 653: Total Demand = 1.57 kWh, Demand Level = 0.00
# Hour 654: Total Demand = 0.13 kWh, Demand Level = 0.00
# Hour 655: Total Demand = 0.72 kWh, Demand Level = 0.00
# Hour 656: Total Demand = 0.74 kWh, Demand Level = 0.00
# Hour 657: Total Demand = 0.54 kWh, Demand Level = 0.00
# Hour 658: Total Demand = 0.10 kWh, Demand Level = 0.00
# Hour 659: Total Demand = 0.12 kWh, Demand Level = 0.00
# Hour 660: Total Demand = 0.13 kWh, Demand Level = 0.00
# Hour 661: Total Demand = 0.24 kWh, Demand Level = 0.00
# Hour 662: Total Demand = 0.18 kWh, Demand Level = 0.00
# Hour 663: Total Demand = 0.14 kWh, Demand Level = 0.00
# Hour 664: Total Demand = 0.17 kWh, Demand Level = 0.00
# Hour 665: Total Demand = 0.34 kWh, Demand Level = 0.00
# Hour 666: Total Demand = 0.63 kWh, Demand Level = 0.00
# Hour 667: Total Demand = 0.41 kWh, Demand Level = 0.00
# Hour 668: Total Demand = 0.24 kWh, Demand Level = 0.00
# Hour 669: Total Demand = 0.18 kWh, Demand Level = 0.00
# Hour 670: Total Demand = 0.18 kWh, Demand Level = 0.00
# Hour 671: Total Demand = 0.17 kWh, Demand Level = 0.00
# Hour 672: Total Demand = 0.09 kWh, Demand Level = 0.00
# Hour 673: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 674: Total Demand = 1.58 kWh, Demand Level = 0.00
# Hour 675: Total Demand = 1.58 kWh, Demand Level = 0.00
# Hour 676: Total Demand = 1.58 kWh, Demand Level = 0.00
# Hour 677: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 678: Total Demand = 0.12 kWh, Demand Level = 0.00
# Hour 679: Total Demand = 0.35 kWh, Demand Level = 0.00
# Hour 680: Total Demand = 0.53 kWh, Demand Level = 0.00
# Hour 681: Total Demand = 0.12 kWh, Demand Level = 0.00
# Hour 682: Total Demand = 0.12 kWh, Demand Level = 0.00
# Hour 683: Total Demand = 0.11 kWh, Demand Level = 0.00
# Hour 684: Total Demand = 0.12 kWh, Demand Level = 0.00
# Hour 685: Total Demand = 0.14 kWh, Demand Level = 0.00
# Hour 686: Total Demand = 0.12 kWh, Demand Level = 0.00
# Hour 687: Total Demand = 0.14 kWh, Demand Level = 0.00
# Hour 688: Total Demand = 0.23 kWh, Demand Level = 0.00
# Hour 689: Total Demand = 0.15 kWh, Demand Level = 0.00
# Hour 690: Total Demand = 0.53 kWh, Demand Level = 0.00
# Hour 691: Total Demand = 0.30 kWh, Demand Level = 0.00
# Hour 692: Total Demand = 1.07 kWh, Demand Level = 0.00
# Hour 693: Total Demand = 0.15 kWh, Demand Level = 0.00
# Hour 694: Total Demand = 0.13 kWh, Demand Level = 0.00
# Hour 695: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 696: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 697: Total Demand = 0.07 kWh, Demand Level = 0.00
# Hour 698: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 699: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 700: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 701: Total Demand = 0.12 kWh, Demand Level = 0.00
# Hour 702: Total Demand = 0.35 kWh, Demand Level = 0.00
# Hour 703: Total Demand = 0.71 kWh, Demand Level = 0.00
# Hour 704: Total Demand = 1.02 kWh, Demand Level = 0.00
# Hour 705: Total Demand = 0.26 kWh, Demand Level = 0.00
# Hour 706: Total Demand = 0.12 kWh, Demand Level = 0.00
# Hour 707: Total Demand = 0.12 kWh, Demand Level = 0.00
# Hour 708: Total Demand = 0.17 kWh, Demand Level = 0.00
# Hour 709: Total Demand = 1.66 kWh, Demand Level = 0.00
# Hour 710: Total Demand = 1.63 kWh, Demand Level = 0.00
# Hour 711: Total Demand = 1.61 kWh, Demand Level = 0.00
# Hour 712: Total Demand = 0.23 kWh, Demand Level = 0.00
# Hour 713: Total Demand = 0.29 kWh, Demand Level = 0.00
# Hour 714: Total Demand = 3.78 kWh, Demand Level = 0.00
# Hour 715: Total Demand = 2.34 kWh, Demand Level = 0.00
# Hour 716: Total Demand = 0.20 kWh, Demand Level = 0.00
# Hour 717: Total Demand = 0.18 kWh, Demand Level = 0.00
# Hour 718: Total Demand = 0.13 kWh, Demand Level = 0.00
# Hour 719: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 720: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 721: Total Demand = 0.09 kWh, Demand Level = 0.00
# Hour 722: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 723: Total Demand = 0.07 kWh, Demand Level = 0.00
# Hour 724: Total Demand = 0.07 kWh, Demand Level = 0.00
# Hour 725: Total Demand = 0.08 kWh, Demand Level = 0.00
# Hour 726: Total Demand = 0.79 kWh, Demand Level = 0.00
# Hour 727: Total Demand = 0.14 kWh, Demand Level = 0.00
# Hour 728: Total Demand = 0.73 kWh, Demand Level = 0.00
# Hour 729: Total Demand = 0.12 kWh, Demand Level = 0.00
# Hour 730: Total Demand = 0.10 kWh, Demand Level = 0.00
# Hour 731: Total Demand = 0.11 kWh, Demand Level = 0.00
# Hour 732: Total Demand = 0.12 kWh, Demand Level = 0.00
# Hour 733: Total Demand = 0.11 kWh, Demand Level = 0.00
# Hour 734: Total Demand = 0.15 kWh, Demand Level = 0.00
# Hour 735: Total Demand = 0.18 kWh, Demand Level = 0.00
# Hour 736: Total Demand = 0.15 kWh, Demand Level = 0.00
# Hour 737: Total Demand = 0.48 kWh, Demand Level = 0.00
# Hour 738: Total Demand = 1.57 kWh, Demand Level = 0.00
# Hour 739: Total Demand = 0.33 kWh, Demand Level = 0.00
# Hour 740: Total Demand = 0.21 kWh, Demand Level = 0.00
# Hour 741: Total Demand = 0.18 kWh, Demand Level = 0.00
# Hour 742: Total Demand = 0.13 kWh, Demand Level = 0.00
# Hour 743: Total Demand = 0.08 kWh, Demand Level = 0.00
